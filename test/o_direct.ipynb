# %%
from o_direct_memmap import open_memmap

# %%
import numpy as np
from numpy.lib.format import open_memmap as np_open_memmap

# %%
m = open_memmap('x4-0')

# %%
np_m = np_open_memmap('x4-0 copy')

# %%
m.shape, np_m.shape, (m != np_m).sum()/np.prod(m.shape)
# Out:
# ((64, 341, 4096), (64, 341, 4096), 0.0)

# %%
m[0, :100, 0]
# Out:
# memmap([0.        , 0.6031113 , 0.16949725, 0.9816996 , 0.9640271 ,
#         0.71199393, 0.6401789 , 0.62459475, 0.1460082 , 0.65329266,
#         0.9404776 , 0.7439612 , 0.8151497 , 0.4969836 , 0.58072746,
#         0.10383391, 0.5102507 , 0.90847254, 0.13069695, 0.6349594 ,
#         0.4709928 , 0.58104306, 0.14192355, 0.7487384 , 0.44271946,
#         0.89209384, 0.3257559 , 0.8687883 , 0.43449622, 0.5908822 ,
#         0.767513  , 0.4633149 , 0.47372866, 0.9234283 , 0.0426594 ,
#         0.2028107 , 0.5615819 , 0.45716685, 0.13776618, 0.8036702 ,
#         0.67492914, 0.27676785, 0.900533  , 0.4697141 , 0.14798641,
#         0.47198975, 0.97940534, 0.93971753, 0.61000323, 0.31785256,
#         0.04871839, 0.03352076, 0.7865669 , 0.2730614 , 0.81675637,
#         0.3730436 , 0.9277363 , 0.78256893, 0.9623991 , 0.7984452 ,
#         0.71890503, 0.19442928, 0.6875608 , 0.8298671 , 0.57147765,
#         0.8063418 , 0.47174847, 0.43691713, 0.41899627, 0.85842955,
# ...

# %%
np_m[0, :100, 0]
# Out:
# memmap([0.        , 0.6031113 , 0.16949725, 0.9816996 , 0.9640271 ,
#         0.71199393, 0.6401789 , 0.62459475, 0.1460082 , 0.65329266,
#         0.9404776 , 0.7439612 , 0.8151497 , 0.4969836 , 0.58072746,
#         0.10383391, 0.5102507 , 0.90847254, 0.13069695, 0.6349594 ,
#         0.4709928 , 0.58104306, 0.14192355, 0.7487384 , 0.44271946,
#         0.89209384, 0.3257559 , 0.8687883 , 0.43449622, 0.5908822 ,
#         0.767513  , 0.4633149 , 0.47372866, 0.9234283 , 0.0426594 ,
#         0.2028107 , 0.5615819 , 0.45716685, 0.13776618, 0.8036702 ,
#         0.67492914, 0.27676785, 0.900533  , 0.4697141 , 0.14798641,
#         0.47198975, 0.97940534, 0.93971753, 0.61000323, 0.31785256,
#         0.04871839, 0.03352076, 0.7865669 , 0.2730614 , 0.81675637,
#         0.3730436 , 0.9277363 , 0.78256893, 0.9623991 , 0.7984452 ,
#         0.71890503, 0.19442928, 0.6875608 , 0.8298671 , 0.57147765,
#         0.8063418 , 0.47174847, 0.43691713, 0.41899627, 0.85842955,
# ...
